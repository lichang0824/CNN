# %% [markdown]
# TODO: test batch size other than 1

# %% [markdown]
# # Preparation

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from IPython.display import clear_output
from sklearn.metrics import r2_score
from BinvoxDataset import CustomDataset

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
import wandb
wandb.login()
# Out:
# True

# %% [markdown]
# # Create dataset

# %%
def transform(voxel):
    return torch.unsqueeze(torch.tensor(voxel, dtype = torch.float32), 0)

# %%
input_folder_path = '../AdditiveParts/data/parts_0, files 1 through 3950/Binvox_files_default_res/'
label_file_path = '../AdditiveParts/data/Tweaker Orientation Score/Tweaker Orientation Score/parts0_1-3950.csv'

# %%
dataset = CustomDataset(input_folder_path = input_folder_path, label_file_path = label_file_path, transform = transform, max_count = None, ram_limit = 1000)
dataset_limited = CustomDataset(input_folder_path = input_folder_path, label_file_path = label_file_path, transform = transform, max_count = 5000, ram_limit = 1000)

# %% [markdown]
# # Define Network

# %%
class ConvNet(nn.Module):
    def __init__(self, kernel_size = 3, activation_fn = nn.ReLU()):
        super().__init__()

        self.max_pooling_2 = nn.MaxPool3d(kernel_size = 2)

        self.up_sampling_2 = nn.Upsample(scale_factor = 2)

        self.conv64_1_8 = nn.Sequential(
            nn.Conv3d(in_channels = 1, out_channels = 8, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 8),
            activation_fn
        )

        self.conv64_8_8 = nn.Sequential(
            nn.Conv3d(in_channels = 8, out_channels = 8, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 8),
            activation_fn
        )

        self.conv32_8_32 = nn.Sequential(
            nn.Conv3d(in_channels = 8, out_channels = 32, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 32),
            activation_fn
        )

        self.conv32_32_32 = nn.Sequential(
            nn.Conv3d(in_channels = 32, out_channels = 32, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 32),
            activation_fn
        )

        self.conv16_32_128 = nn.Sequential(
            nn.Conv3d(in_channels = 32, out_channels = 128, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 128),
            activation_fn
        )

        self.conv16_128_128 = nn.Sequential(
            nn.Conv3d(in_channels = 128, out_channels = 128, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 128),
            activation_fn
        )

        self.conv8_128_256 = nn.Sequential(
            nn.Conv3d(in_channels = 128, out_channels = 256, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 256),
            activation_fn
        )

        self.conv8_256_256 = nn.Sequential(
            nn.Conv3d(in_channels = 256, out_channels = 256, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 256),
            activation_fn
        )

        self.conv16_384_128 = nn.Sequential(
            nn.Conv3d(in_channels = 384, out_channels = 128, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 128),
            activation_fn
        )

        self.conv32_160_32 = nn.Sequential(
            nn.Conv3d(in_channels = 160, out_channels = 32, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 32),
            activation_fn
        )

        self.conv64_40_8 = nn.Sequential(
            nn.Conv3d(in_channels = 40, out_channels = 8, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 8),
            activation_fn
        )

        self.conv64_8_1 = nn.Sequential(
            nn.Conv3d(in_channels = 8, out_channels = 1, kernel_size = kernel_size, padding = 'same'),
            activation_fn
        )

    def forward(self, x):
        x = self.conv64_1_8(x)
        x = self.conv64_8_8(x)
        feature_map_64 = x.detach()
        x = self.max_pooling_2(x)
        x = self.conv32_8_32(x)
        x = self.conv32_32_32(x)
        feature_map_32 = x.detach()
        x = self.max_pooling_2(x)
        x = self.conv16_32_128(x)
        x = self.conv16_128_128(x)
        feature_map_16 = x.detach()
        x = self.max_pooling_2(x)
        x = self.conv8_128_256(x)
        x = self.conv8_256_256(x)
        x = self.up_sampling_2(x)
        x = torch.cat((feature_map_16, x), dim = 1)
        x = self.conv16_384_128(x)
        x = self.conv16_128_128(x)
        x = self.up_sampling_2(x)
        x = torch.cat((feature_map_32, x), dim = 1)
        x = self.conv32_160_32(x)
        x = self.conv32_32_32(x)
        x = self.up_sampling_2(x)
        x = torch.cat((feature_map_64, x), dim = 1)
        x = self.conv64_40_8(x)
        x = self.conv64_8_1(x)
        return x

# %%
class ConvNetScalarLabel(nn.Module):
    def __init__(self, kernel_size = 3, activation_fn = nn.ReLU()):
        super().__init__()

        self.max_pooling_2 = nn.MaxPool3d(kernel_size = 2)
        self.max_pooling_1 = nn.MaxPool3d(kernel_size = 1)

        self.conv256_1_2 = nn.Sequential(
            nn.Conv3d(in_channels = 1, out_channels = 2, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 2),
            activation_fn
        )

        self.conv256_2_2 = nn.Sequential(
            nn.Conv3d(in_channels = 2, out_channels = 2, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 2),
            activation_fn
        )

        self.conv128_2_4 = nn.Sequential(
            nn.Conv3d(in_channels = 2, out_channels = 4, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 4),
            activation_fn
        )

        self.conv128_4_4 = nn.Sequential(
            nn.Conv3d(in_channels = 4, out_channels = 4, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 4),
            activation_fn
        )

        self.conv64_4_8 = nn.Sequential(
            nn.Conv3d(in_channels = 4, out_channels = 8, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 8),
            activation_fn
        )

        self.conv64_8_8 = nn.Sequential(
            nn.Conv3d(in_channels = 8, out_channels = 8, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 8),
            activation_fn
        )

        self.conv32_8_32 = nn.Sequential(
            nn.Conv3d(in_channels = 8, out_channels = 32, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 32),
            activation_fn
        )

        self.conv32_32_32 = nn.Sequential(
            nn.Conv3d(in_channels = 32, out_channels = 32, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 32),
            activation_fn
        )

        self.conv16_32_128 = nn.Sequential(
            nn.Conv3d(in_channels = 32, out_channels = 128, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 128),
            activation_fn
        )

        self.conv16_128_128 = nn.Sequential(
            nn.Conv3d(in_channels = 128, out_channels = 128, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 128),
            activation_fn
        )

        self.conv8_128_256 = nn.Sequential(
            nn.Conv3d(in_channels = 128, out_channels = 256, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 256),
            activation_fn
        )

        self.conv8_256_256 = nn.Sequential(
            nn.Conv3d(in_channels = 256, out_channels = 256, kernel_size = kernel_size, padding = 'same'),
            nn.BatchNorm3d(num_features = 256),
            activation_fn
        )

        self.conv4_256_32 = nn.Sequential(
            nn.Conv3d(in_channels = 256, out_channels = 32, kernel_size = 3, padding = 'same'),
            nn.BatchNorm3d(num_features = 32),
            activation_fn
        )

        self.conv4_32_32 = nn.Sequential(
            nn.Conv3d(in_channels = 32, out_channels = 32, kernel_size = 3, padding = 'same'),
            nn.BatchNorm3d(num_features = 32),
            activation_fn
        )

        self.conv2_32_1 = nn.Sequential(
            nn.Conv3d(in_channels = 32, out_channels = 1, kernel_size = 1, padding = 'same'),
            nn.BatchNorm3d(num_features = 1),
            activation_fn
        )

    def forward(self, x):
        x = self.conv256_1_2(x)
        x = self.conv256_2_2(x)
        x = self.max_pooling_2(x)
        x = self.conv128_2_4(x)
        x = self.conv128_4_4(x)
        x = self.max_pooling_2(x)
        x = self.conv64_4_8(x)
        x = self.conv64_8_8(x)
        x = self.max_pooling_2(x)
        x = self.conv32_8_32(x)
        x = self.conv32_32_32(x)
        x = self.max_pooling_2(x)
        x = self.conv16_32_128(x)
        x = self.conv16_128_128(x)
        x = self.max_pooling_2(x)
        x = self.conv8_128_256(x)
        x = self.conv8_256_256(x)
        x = self.max_pooling_2(x)
        x = self.conv4_256_32(x)
        x = self.conv4_32_32(x)
        x = self.max_pooling_2(x)
        x = self.conv2_32_1(x)
        x = self.max_pooling_2(x)
        # print('outcome shape', torch.squeeze(x).shape)
        # return torch.reshape(x, (x.shape[0], 1))
        return torch.squeeze(x)

# %% [markdown]
# # Define Training Logic

# %%
def train_epoch(model, training_loader, optimizer, loss_fn):
    cumulative_loss = 0.0
    for i, data in enumerate(training_loader):
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        labels = torch.squeeze(labels)

        # Zero the gradients
        optimizer.zero_grad()

        # Make predictions
        outputs = model(inputs)

        # Compute loss and its gradients
        # print('label shape', labels.shape)
        loss = loss_fn(outputs, labels)
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        cumulative_loss += loss.item()
        
        wandb.log({'batch loss': loss.item()})
    return cumulative_loss / len(training_loader), cumulative_loss

# %%
def train(config, loss_fn):
    clear_output(wait = True)
    
    # initialize a wandb run
    wandb.init(config = config)

    # copy the config
    config = wandb.config
    
    print('config:', config)

    # get training loader
    training_loader = DataLoader(dataset, batch_size = config.batch_size, shuffle = False)

    # initialize model
    if config.activation_fn == 'ReLU':
        activation_fn = nn.ReLU()
    
    if config.activation_fn == 'Sigmoid':
        activation_fn = nn.Sigmoid()
    
    model = ConvNetScalarLabel(kernel_size = config.kernel_size, activation_fn = activation_fn).to(device)
    
    optimizer = torch.optim.SGD(model.parameters(), lr = config.learning_rate, momentum = 0.9)

    for epoch in range(config.epochs_choice):
        avg_loss_per_batch, cumulative_loss = train_epoch(model, training_loader, optimizer, loss_fn)
        wandb.log({'avg_loss_per_batch': avg_loss_per_batch, 'cumulative_loss': cumulative_loss})
        print(f'Loss for epoch {epoch}: {cumulative_loss}')
    
    return model

# %%
def test(config, model, loss_fn):
    # copy the config
    config = wandb.config
    
    # get testing loader
    testing_loader = DataLoader(dataset_limited, batch_size = config.batch_size, shuffle = False)
    
    testing_loss = 0.0
    y_true = []
    y_pred = []
    for i, data in enumerate(testing_loader):
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        testing_loss += loss.item()

        y_true.extend(labels.cpu().numpy().tolist())
        y_pred.extend(outputs.cpu().detach().numpy().tolist())
    return testing_loss / len(testing_loader), testing_loss, r2_score(y_true = y_true, y_pred = y_pred)

# %%
def evaluate(config = None):
    loss_fn = nn.MSELoss()
    model = train(config, loss_fn)
    avg_loss_per_batch_test, testing_loss, r2 = test(config, model, loss_fn)
    wandb.log({'avg_loss_per_batch_test': avg_loss_per_batch_test, 'testing_loss': testing_loss, 'r2': r2})

# %% [markdown]
# # Training settings

# %%
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'testing_loss',
    'goal': 'minimize'
    }
sweep_config['metric'] = metric
parameters_dict = {
    'kernel_size': {
        'values': [3, 4, 5]
    },
    'activation_fn': {
        'values': ['ReLU', 'Sigmoid']
    },
    'epochs_choice': {
          'values': [5, 10, 20]
    },
    'learning_rate': {
        'values': [1e-4, 1e-3, 1e-2]
    },
    'batch_size': {
        'values': [8, 4]
    },
}

parameters_dict = {
    'kernel_size': {
        'values': [3]
    },
    'activation_fn': {
        'values': ['ReLU']
    },
    'epochs_choice': {
          'values': [5]
    },
    'learning_rate': {
        'values': [1e-3]
    },
    'batch_size': {
        'values': [4]
    },
}

sweep_config['parameters'] = parameters_dict

# %% [markdown]
# # Start

# %%
sweep_id = wandb.sweep(sweep_config, project = 'CNN_sweep_scalar')
# Out:
# Create sweep with ID: kcskbsf4
# Sweep URL: https://wandb.ai/changli_824/CNN_sweep_scalar/sweeps/kcskbsf4

# %%
wandb.agent(sweep_id = sweep_id, function = evaluate)
# Out:
# config: {'activation_fn': 'ReLU', 'batch_size': 4, 'epochs_choice': 5, 'kernel_size': 3, 'learning_rate': 0.001}
# Loading samples 0 through 999
# Process SpawnPoolWorker-1:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-2:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-4:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-3:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-8:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-7:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-6:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-9:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-11:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-10:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-12:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-13:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-15:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-14:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-16:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-17:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-20:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-21:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-18:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-19:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-22:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-23:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-24:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-25:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-26:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-28:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-27:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-29:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-30:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-31:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-32:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-33:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-34:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-36:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-35:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-37:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-38:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-39:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-40:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-41:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-43:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-42:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-45:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-44:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-46:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-47:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-48:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'transform' on <module '__main__' (built-in)>
# wandb: Ctrl + C detected. Stopping sweep.
# Process SpawnPoolWorker-52:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/lichang/CNN/BinvoxDataset.py", line 5, in <module>
#     from torch.utils.data import Dataset
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 1187, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/functional.py", line 8, in <module>
#     import torch.nn.functional as F
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/nn/__init__.py", line 7, in <module>
#     from .parallel import DataParallel as DataParallel
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/nn/parallel/__init__.py", line 5, in <module>
#     from .distributed import DistributedDataParallel
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/nn/parallel/distributed.py", line 27, in <module>
#     from torch.distributed.utils import (
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1033, in get_data
# KeyboardInterrupt
# Process SpawnPoolWorker-53:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/lichang/CNN/BinvoxDataset.py", line 5, in <module>
#     from torch.utils.data import Dataset
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 1239, in <module>
#     from torch import onnx as onnx
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/__init__.py", line 12, in <module>
#     from . import (  # usort:skip. Keep the order instead of sorting lexicographically
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/errors.py", line 9, in <module>
#     from torch.onnx._internal import diagnostics
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/_internal/diagnostics/__init__.py", line 1, in <module>
#     from ._diagnostic import (
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/_internal/diagnostics/_diagnostic.py", line 10, in <module>
#     from torch.onnx._internal.diagnostics import infra
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/_internal/diagnostics/infra/__init__.py", line 1, in <module>
#     from ._infra import (
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/_internal/diagnostics/infra/_infra.py", line 10, in <module>
#     from torch.onnx._internal.diagnostics.infra import formatter, sarif
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/_internal/diagnostics/infra/formatter.py", line 7, in <module>
#     from torch.onnx._internal.diagnostics.infra import sarif
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/_internal/diagnostics/infra/sarif/__init__.py", line 71, in <module>
#     from torch.onnx._internal.diagnostics.infra.sarif._run import Run
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/onnx/_internal/diagnostics/infra/sarif/_run.py", line 31, in <module>
#     class Run(object):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/dataclasses.py", line 1019, in dataclass
#     return wrap(cls)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/dataclasses.py", line 1011, in wrap
#     return _process_class(cls, init, repr, eq, order, unsafe_hash, frozen)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/dataclasses.py", line 951, in _process_class
#     _cmp_fn('__eq__', '==',
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/dataclasses.py", line 579, in _cmp_fn
#     return _create_fn(name,
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/dataclasses.py", line 398, in _create_fn
#     exec(txt, globals, ns)
#   File "<string>", line 1, in <module>
# KeyboardInterrupt
# Process SpawnPoolWorker-50:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/lichang/CNN/BinvoxDataset.py", line 5, in <module>
#     from torch.utils.data import Dataset
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 1247, in <module>
#     import torch.backends.mps
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/backends/mps/__init__.py", line 30, in <module>
#     from ..._refs import var_mean as _var_mean, native_group_norm as _native_group_norm
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_refs/__init__.py", line 14, in <module>
#     import torch._prims as prims
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_prims/__init__.py", line 33, in <module>
#     from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_subclasses/__init__.py", line 3, in <module>
#     from torch._subclasses.fake_tensor import (
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#     from torch._guards import Source
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_guards.py", line 14, in <module>
#     import sympy  # type: ignore[import]
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/__init__.py", line 51, in <module>
#     from .core import (sympify, SympifyError, cacheit, Basic, Atom,
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/__init__.py", line 4, in <module>
#     from .sympify import sympify, SympifyError
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/sympify.py", line 635, in <module>
#     from .basic import Basic
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 8, in <module>
#     from .assumptions import ManagedProperties
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/assumptions.py", line 220, in <module>
#     _assume_rules = FactRules([
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/facts.py", line 442, in __init__
#     impl_ab = apply_beta_to_alpha_route(impl_a, P.rules_beta)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/facts.py", line 182, in apply_beta_to_alpha_route
#     x_all = ximpls | {x}
# KeyboardInterrupt
# Process SpawnPoolWorker-51:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/lichang/CNN/BinvoxDataset.py", line 5, in <module>
#     from torch.utils.data import Dataset
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 1247, in <module>
#     import torch.backends.mps
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/backends/mps/__init__.py", line 30, in <module>
#     from ..._refs import var_mean as _var_mean, native_group_norm as _native_group_norm
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_refs/__init__.py", line 14, in <module>
#     import torch._prims as prims
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_prims/__init__.py", line 33, in <module>
#     from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_subclasses/__init__.py", line 3, in <module>
#     from torch._subclasses.fake_tensor import (
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#     from torch._guards import Source
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_guards.py", line 14, in <module>
#     import sympy  # type: ignore[import]
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/__init__.py", line 51, in <module>
#     from .core import (sympify, SympifyError, cacheit, Basic, Atom,
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/__init__.py", line 4, in <module>
#     from .sympify import sympify, SympifyError
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/sympify.py", line 635, in <module>
#     from .basic import Basic
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 8, in <module>
#     from .assumptions import ManagedProperties
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/assumptions.py", line 220, in <module>
#     _assume_rules = FactRules([
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/facts.py", line 442, in __init__
#     impl_ab = apply_beta_to_alpha_route(impl_a, P.rules_beta)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/facts.py", line 182, in apply_beta_to_alpha_route
#     x_all = ximpls | {x}
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/sympy/core/logic.py", line 237, in __hash__
#     return hash((type(self).__name__,) + tuple(self.args))
# KeyboardInterrupt
# Process SpawnPoolWorker-55:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/lichang/CNN/BinvoxDataset.py", line 5, in <module>
#     from torch.utils.data import Dataset
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 229, in <module>
#     from torch._C import *  # noqa: F403
# KeyboardInterrupt
# Process SpawnPoolWorker-54:
# Traceback (most recent call last):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/lichang/CNN/BinvoxDataset.py", line 5, in <module>
#     from torch.utils.data import Dataset
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 1187, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/functional.py", line 8, in <module>
#     import torch.nn.functional as F
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/__init__.py", line 2, in <module>
#     from .linear import Identity, Linear, Bilinear, LazyLinear
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py", line 7, in <module>
#     from .. import functional as F
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py", line 19, in <module>
#     from .._jit_internal import boolean_dispatch, _overload, BroadcastingList1, BroadcastingList2, BroadcastingList3
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/_jit_internal.py", line 40, in <module>
#     import torch.distributed.rpc
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/distributed/__init__.py", line 58, in <module>
#     from .distributed_c10d import *  # noqa: F403
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/distributed/distributed_c10d.py", line 35, in <module>
#     from torch.autograd.profiler import record_function
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py", line 26, in <module>
#     from . import graph
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/graph.py", line 299, in <module>
#     def register_multi_grad_hook(tensors: Sequence[torch.Tensor], fn: Callable[[Sequence[Optional[torch.Tensor]]], None]):
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/typing.py", line 816, in __getitem__
#     return self.__getitem_inner__(params)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/typing.py", line 258, in inner
#     return cached(*args, **kwds)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/typing.py", line 841, in __getitem_inner__
#     return self.copy_with(params)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/typing.py", line 691, in copy_with
#     return _GenericAlias(self.__origin__, params, name=self._name, inst=self._inst)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/typing.py", line 672, in __init__
#     self.__parameters__ = _collect_type_vars(params)
#   File "/Users/lichang/opt/anaconda3/lib/python3.8/site-packages/typing_extensions.py", line 198, in _collect_type_vars
#     tvars.extend([t for t in t.__parameters__ if t not in tvars])
# KeyboardInterrupt
